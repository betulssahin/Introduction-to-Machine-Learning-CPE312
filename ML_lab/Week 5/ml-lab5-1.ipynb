# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/kaggle/input/machineleraning-lab4/linear_regression_dataset.csv")

# %%
df
# Out:
#    deneyim;maas
# 0      0.5;2500
# 1        0;2250
# 2        1;2750
# 3        5;8000
# 4        8;9000
# 5        4;6900
# 6      15;20000
# 7        7;8500
# 8        3;6000
# 9        2;3500
# 10     12;15000
# 11     10;13000
# 12     14;18000
# 13       6;7500

# %%
df=pd.read_csv("/kaggle/input/machineleraning-lab4/linear_regression_dataset.csv", sep=";")

# %%
df.head()
# Out:
#    deneyim  maas
# 0      0.5  2500
# 1      0.0  2250
# 2      1.0  2750
# 3      5.0  8000
# 4      8.0  9000

# %%
plt.scatter(df.deneyim,df.maas)
plt.xlabel("experinece")
plt.ylabel("salary")
plt.show()

# %%
x=df.deneyim.values

# %%
x.shape
# Out:
# (14,)

# %%
x=df.deneyim.values.reshape(-1,1)
y=df.maas.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
linear_reg=LinearRegression()
linear_reg.fit(x,y)
# Out:
# LinearRegression()

# %%
b0=linear_reg.predict([[0]])
print("b0: ", b0)
# Out:
# b0:  [[1663.89519747]]

# %%
b0_=linear_reg.intercept_
print("b0: ", b0_)
# Out:
# b0:  [1663.89519747]

# %%
b1=linear_reg.coef_
print("b1: ", b1)
# Out:
# b1:  [[1138.34819698]]

# %% [markdown]
# Y=B0+B1*X

# %%
new_salary=1663+1138*11
print(new_salary)
# Out:
# 14181

# %%
b11=linear_reg.predict([[11]])
print("b11: ", b11)
# Out:
# b11:  [[14185.72536421]]

# %%
y_head = linear_reg.predict(x)

# %%
plt.plot(x, y_head, color="red")
plt.scatter(x,y)
plt.show()

# %%
from sklearn.metrics import r2_score
print("r square score", r2_score(y,y_head))
# Out:
# r square score 0.9775283164949903

# %%
from sklearn.metrics import mean_squared_error
print("Mean Squared Error: ",mean_squared_error(y,y_head))
# Out:
# Mean Squared Error:  685945.845961494

# %%
MSE = np.square(np.subtract(y,y_head)).mean()
print("Mean Squared Error: ",MSE)
# Out:
# Mean Squared Error:  685945.845961494
